# %%
#charcteristics
#ordrd collection
t=(1,2,3,[10,30,40],25)

# %%
# immutable
# after operation it does not the length of object and does not change the remaining element positions
t=(1,2,3,[10,30,40],25)
t[3].append(100)
print(t)
# Out:
# (1, 2, 3, [10, 30, 40, 100], 25)

# %%
# empty tuple representation
# single element representaion
t1=()
t2=()
print(type(t1),type(t2))
# Out:
# <class 'tuple'> <class 'tuple'>

# %%
# single element representaion
t1=(10)
t2=(10,)
l1=[10]
print(type(t1),type(l1),type(t2))
# Out:
# <class 'int'> <class 'list'> <class 'tuple'>

# %%
# Method 
# index()
# count()

# %%
# Tuple operations
#Tuple concatenation
# Tuple Repeatation
