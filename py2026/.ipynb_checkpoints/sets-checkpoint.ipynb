# %%
### set characteristics

# %%
# set unordered collection 
# set reder unique elements ,sets does not allow duplicates 
s={1,2,3,2,3,'hi','a',2.02,(10,20,30)}
print(s)
print(s[0])# set does not support indexing
# Out:
# {1, 2, 3, 2.02, 'hi', 'a', (10, 20, 30)}

# %%
print(10,6,3,5)
# Out:
# 10 6 3 5

# %%
# list can't be used as set element 
s={1,2,[3,2,3],'hi','a',2.02,(10,20,30)}
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s={1,2,[3,2,3],'hi','a',2.02,(10,20,30)}
#       2 print(s)
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')
