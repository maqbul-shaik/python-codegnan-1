# %%
name='mq'
age= 20
print('my name is', name +   'iam' ,str(age), 'years old')
# Out:
# my name is mqiam 20 years old

# %%
#Access Specifiers 
#string-%s
#integer-%d
#float-%f
name="virat"
age = 20
print("my name is %s and i am %d years old"% (name,age))
# Out:
# my name is virat and i am 20 years old

# %%
# dot formatting
name="virat"
age = 20
print("my name is {} and i am {} years old".format(name,age))
# Out:
# my name is virat and i am 20 years old

# %%
# f-format
name="virat"
age = 20
print(f"my name is {name} and i am {age} years old" )
# Out:
# my name is virat and i am 20 years old
